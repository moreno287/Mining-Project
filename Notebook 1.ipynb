# %%
# Data Manipulation Tool
# !pip install pandas
import pandas as pd

# Data Visualization Tools
# !pip install seaborn
import seaborn as sns

# !pip install matplotlib
import matplotlib.pyplot as plt
# Out:
# Requirement already satisfied: pandas in /root/venv/lib/python3.11/site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in /root/venv/lib/python3.11/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /root/venv/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: seaborn in /root/venv/lib/python3.11/site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /root/venv/lib/python3.11/site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in /root/venv/lib/python3.11/site-packages (from seaborn) (2.1.4)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /root/venv/lib/python3.11/site-packages (from seaborn) (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /root/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /root/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /root/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /root/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /root/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /root/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.11/site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: matplotlib in /root/venv/lib/python3.11/site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /root/venv/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.11/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /root/venv/lib/python3.11/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.21 in /root/venv/lib/python3.11/site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /root/venv/lib/python3.11/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /root/venv/lib/python3.11/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /root/venv/lib/python3.11/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /root/venv/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
df = pd.read_csv('MiningProcess-Flotation-Plant-Database.csv', decimal=',')

# %%
df.head()
# Out:
#                   date  % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# 0  2017-03-10 01:00:00         55.2          16.98      3019.53     557.434
# 1  2017-03-10 01:00:00         55.2          16.98      3024.41     563.965
# 2  2017-03-10 01:00:00         55.2          16.98      3043.46     568.054
# 3  2017-03-10 01:00:00         55.2          16.98      3047.36     568.665
# 4  2017-03-10 01:00:00         55.2          16.98      3033.69     558.167
#
#    Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# 0        395.713      10.0664              1.74                       249.214
# 1        397.383      10.0672              1.74                       249.719
# 2        399.668      10.0680              1.74                       249.741
# 3        397.939      10.0689              1.74                       249.917
# 4        400.254      10.0697              1.74                       250.203
#
#    Flotation Column 02 Air Flow  ...  Flotation Column 07 Air Flow  \
# 0                       253.235  ...                       250.884
# 1                       250.532  ...                       248.994
# 2                       247.874  ...                       248.071
# 3                       254.487  ...                       251.147
# 4                       252.136  ...                       248.928
#
#    Flotation Column 01 Level  Flotation Column 02 Level  \
# 0                    457.396                    432.962
# 1                    451.891                    429.560
# 2                    451.240                    468.927
# 3                    452.441                    458.165
# 4                    452.441                    452.900
#
#    Flotation Column 03 Level  Flotation Column 04 Level  \
# 0                    424.954                    443.558
# 1                    432.939                    448.086
# 2                    434.610                    449.688
# 3                    442.865                    446.210
# 4                    450.523                    453.670
#
#    Flotation Column 05 Level  Flotation Column 06 Level  \
# 0                    502.255                    446.370
# 1                    496.363                    445.922
# 2                    484.411                    447.826
# 3                    471.411                    437.690
# 4                    462.598                    443.682
#
#    Flotation Column 07 Level  % Iron Concentrate  % Silica Concentrate
# 0                    523.344               66.91                  1.31
# 1                    498.075               66.91                  1.31
# 2                    458.567               66.91                  1.31
# 3                    427.669               66.91                  1.31
# 4                    425.679               66.91                  1.31
#
# [5 rows x 24 columns]

# %%
df.shape
# Out:
# (737453, 24)

# %%
df['% Iron Concentrate']
# Out:
# 0         66.91
# 1         66.91
# 2         66.91
# 3         66.91
# 4         66.91
#           ...
# 737448    64.27
# 737449    64.27
# 737450    64.27
# 737451    64.27
# 737452    64.27
# Name: % Iron Concentrate, Length: 737453, dtype: float64

# %%
df.iloc[50:61, :]
# Out:
#                    date  % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# 50  2017-03-10 01:00:00         55.2          16.98      1084.31     597.046
# 51  2017-03-10 01:00:00         55.2          16.98      1037.76     597.168
# 52  2017-03-10 01:00:00         55.2          16.98      2588.77     597.900
# 53  2017-03-10 01:00:00         55.2          16.98      3026.46     598.755
# 54  2017-03-10 01:00:00         55.2          16.98      2962.89     598.755
# 55  2017-03-10 01:00:00         55.2          16.98      2926.07     607.086
# 56  2017-03-10 01:00:00         55.2          16.98      2940.53     600.861
# 57  2017-03-10 01:00:00         55.2          16.98      2951.37     593.506
# 58  2017-03-10 01:00:00         55.2          16.98      2975.20     598.602
# 59  2017-03-10 01:00:00         55.2          16.98      3053.71     599.823
# 60  2017-03-10 01:00:00         55.2          16.98      3094.24     596.375
#
#     Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  \
# 50        403.667      10.1257           1.74091
# 51        398.687      10.1273           1.74126
# 52        394.556      10.1288           1.74160
# 53        397.471      10.1303           1.74195
# 54        399.316      10.1307           1.74229
# 55        395.508      10.1305           1.74264
# 56        396.694      10.1302           1.74298
# 57        398.818      10.1300           1.74333
# 58        398.452      10.1298           1.74367
# 59        399.097      10.1295           1.74402
# 60        397.896      10.1293           1.74436
#
#     Flotation Column 01 Air Flow  Flotation Column 02 Air Flow  ...  \
# 50                       252.554                       250.258  ...
# 51                       252.532                       249.346  ...
# 52                       252.971                       248.302  ...
# 53                       252.839                       248.785  ...
# 54                       252.686                       249.170  ...
# 55                       253.257                       250.884  ...
# 56                       252.993                       250.950  ...
# 57                       252.114                       255.344  ...
# 58                       252.092                       251.104  ...
# 59                       252.532                       249.412  ...
# 60                       252.114                       249.489  ...
#
#     Flotation Column 07 Air Flow  Flotation Column 01 Level  \
# 50                       249.851                    460.474
# 51                       249.818                    451.240
# 52                       250.620                    443.232
# 53                       250.642                    455.720
# 54                       250.488                    463.953
# 55                       250.203                    459.073
# 56                       249.906                    461.325
# 57                       249.972                    463.953
# 58                       250.334                    454.193
# 59                       249.774                    441.456
# 60                       249.390                    440.029
#
#     Flotation Column 02 Level  Flotation Column 03 Level  \
# 50                   500.7590                    432.014
# 51                   514.1300                    432.423
# 52                   509.5950                    431.370
# 53                   507.8110                    444.560
# 54                   509.2000                    452.680
# 55                   506.9900                    458.998
# 56                   261.3410                    455.731
# 57                   314.7245                    457.756
# 58                   368.1080                    468.145
# 59                   509.6250                    460.182
# 60                   524.3780                    460.773
#
#     Flotation Column 04 Level  Flotation Column 05 Level  \
# 50                    428.375                    505.236
# 51                    398.964                    489.674
# 52                    412.658                    470.205
# 53                    442.855                    473.921
# 54                    453.520                    480.280
# 55                    454.788                    483.147
# 56                    461.307                    483.975
# 57                    461.148                    492.540
# 58                    450.738                    480.531
# 59                    423.496                    463.592
# 60                    423.264                    447.176
#
#     Flotation Column 06 Level  Flotation Column 07 Level  % Iron Concentrate  \
# 50                    503.518                    551.869               66.91
# 51                    506.402                    535.315               66.91
# 52                    476.022                    487.337               66.91
# 53                    431.803                    439.941               66.91
# 54                    416.120                    424.300               66.91
# 55                    421.580                    401.706               66.91
# 56                    445.638                    395.280               66.91
# 57                    482.854                    418.455               66.91
# 58                    499.318                    452.579               66.91
# 59                    495.594                    478.403               66.91
# 60                    472.102                    479.453               66.91
#
#     % Silica Concentrate
# 50                  1.31
# 51                  1.31
# 52                  1.31
# 53                  1.31
# 54                  1.31
# 55                  1.31
# 56                  1.31
# 57                  1.31
# 58                  1.31
# 59                  1.31
# 60                  1.31
#
# [11 rows x 24 columns]

# %%
# 1. Check the Container
print(type(df))

# 2. Check the Column
print(type(df['date']))

# 3. Check the First Value inside the column (The Important One)
print(type(df['date'][0]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>
# <class 'str'>

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df.describe()
# Out:
#                                 date    % Iron Feed  % Silica Feed  \
# count                         737453  737453.000000  737453.000000
# mean   2017-06-16 03:27:22.656549376      56.294739      14.651716
# min              2017-03-10 01:00:00      42.740000       1.310000
# 25%              2017-05-04 23:00:00      52.670000       8.940000
# 50%              2017-06-16 15:00:00      56.080000      13.850000
# 75%              2017-07-29 07:00:00      59.720000      19.600000
# max              2017-09-09 23:00:00      65.780000      33.400000
# std                              NaN       5.157744       6.807439
#
#          Starch Flow     Amina Flow  Ore Pulp Flow    Ore Pulp pH  \
# count  737453.000000  737453.000000  737453.000000  737453.000000
# mean     2869.140569     488.144697     397.578372       9.767639
# min         0.002026     241.669000     376.249000       8.753340
# 25%      2076.320000     431.796000     394.264000       9.527360
# 50%      3018.430000     504.393000     399.249000       9.798100
# 75%      3727.730000     553.257000     402.968000      10.038000
# max      6300.230000     739.538000     418.641000      10.808100
# std      1215.203734      91.230534       9.699785       0.387007
#
#        Ore Pulp Density  Flotation Column 01 Air Flow  \
# count     737453.000000                 737453.000000
# mean           1.680380                    280.151856
# min            1.519820                    175.510000
# 25%            1.647310                    250.281000
# 50%            1.697600                    299.344000
# 75%            1.728330                    300.149000
# max            1.853250                    373.871000
# std            0.069249                     29.621288
#
#        Flotation Column 02 Air Flow  ...  Flotation Column 07 Air Flow  \
# count                 737453.000000  ...                 737453.000000
# mean                     277.159965  ...                    290.754856
# min                      175.156000  ...                    185.962000
# 25%                      250.457000  ...                    256.302000
# 50%                      296.223000  ...                    299.011000
# 75%                      300.690000  ...                    301.904000
# max                      375.992000  ...                    371.593000
# std                       30.149357  ...                     28.670105
#
#        Flotation Column 01 Level  Flotation Column 02 Level  \
# count              737453.000000              737453.000000
# mean                  520.244823                 522.649555
# min                   149.218000                 210.752000
# 25%                   416.978000                 441.883000
# 50%                   491.878000                 495.956000
# 75%                   594.114000                 595.464000
# max                   862.274000                 828.919000
# std                   131.014924                 128.165050
#
#        Flotation Column 03 Level  Flotation Column 04 Level  \
# count              737453.000000              737453.000000
# mean                  531.352662                 420.320973
# min                   126.255000                 162.201000
# 25%                   411.325000                 356.679000
# 50%                   494.318000                 411.974000
# 75%                   601.249000                 485.549000
# max                   886.822000                 680.359000
# std                   150.842164                  91.794432
#
#        Flotation Column 05 Level  Flotation Column 06 Level  \
# count              737453.000000              737453.000000
# mean                  425.251706                 429.941018
# min                   166.991000                 155.841000
# 25%                   357.653000                 358.497000
# 50%                   408.773000                 424.664575
# 75%                   484.329000                 492.684000
# max                   675.644000                 698.861000
# std                    84.535822                  89.862225
#
#        Flotation Column 07 Level  % Iron Concentrate  % Silica Concentrate
# count              737453.000000       737453.000000         737453.000000
# mean                  421.021231           65.050068              2.326763
# min                   175.349000           62.050000              0.600000
# 25%                   356.772000           64.370000              1.440000
# 50%                   411.065000           65.210000              2.000000
# 75%                   476.465000           65.860000              3.010000
# max                   659.902000           68.010000              5.530000
# std                    84.891491            1.118645              1.125554
#
# [8 rows x 24 columns]

# %%
# Find the range of dates
max_date = df['date'].max()
print('The max date is ' + str(max_date))

min_date = df['date'].min()
print('The min date is ' + str(min_date))
# Out:
# The max date is 2017-09-09 23:00:00
# The min date is 2017-03-10 01:00:00

# %%
df_june = df[(df['date'] > "2017-05-31 23:59:59") &(df['date'] < "2017-06-02")].reset_index(drop=True)

# %%
df_june.head()
# Out:
#         date  % Iron Feed  % Silica Feed  Starch Flow  Amina Flow  \
# 0 2017-06-01        64.03           6.26      2964.08     457.908
# 1 2017-06-01        64.03           6.26      2972.19     458.139
# 2 2017-06-01        64.03           6.26      2980.30     458.369
# 3 2017-06-01        64.03           6.26      3036.45     457.847
# 4 2017-06-01        64.03           6.26      3068.72     459.983
#
#    Ore Pulp Flow  Ore Pulp pH  Ore Pulp Density  Flotation Column 01 Air Flow  \
# 0        394.968      9.55029           1.63544                       300.522
# 1        393.641      9.55201           1.63574                       300.771
# 2        392.313      9.55373           1.63604                       301.020
# 3        402.497      9.55544           1.63634                       301.015
# 4        396.253      9.55716           1.63664                       301.085
#
#    Flotation Column 02 Air Flow  ...  Flotation Column 07 Air Flow  \
# 0                       303.714  ...                       298.360
# 1                       300.644  ...                       297.613
# 2                       297.575  ...                       296.866
# 3                       296.245  ...                       303.630
# 4                       304.795  ...                       299.320
#
#    Flotation Column 01 Level  Flotation Column 02 Level  \
# 0                    610.041                    601.107
# 1                    604.373                    604.956
# 2                    598.705                    608.805
# 3                    589.618                    604.796
# 4                    583.780                    609.901
#
#    Flotation Column 03 Level  Flotation Column 04 Level  \
# 0                    590.212                    571.422
# 1                    591.842                    567.588
# 2                    593.471                    563.754
# 3                    593.901                    550.891
# 4                    603.054                    560.003
#
#    Flotation Column 05 Level  Flotation Column 06 Level  \
# 0                    522.585                    497.025
# 1                    497.841                    509.922
# 2                    473.097                    522.820
# 3                    455.752                    525.917
# 4                    475.140                    507.331
#
#    Flotation Column 07 Level  % Iron Concentrate  % Silica Concentrate
# 0                    511.078               64.46                  1.73
# 1                    538.574               64.46                  1.73
# 2                    566.070               64.46                  1.73
# 3                    585.765               64.46                  1.73
# 4                    572.310               64.46                  1.73
#
# [5 rows x 24 columns]

# %%
# 1. Create a list of the columns we want
important_cols = ['date', '% Iron Concentrate', '% Silica Concentrate', 'Ore Pulp pH', 'Flotation Column 05 Level']

# 2. Apply that list to our dataframe
df_june_important = df_june[important_cols]

# 3. View the final result
df_june_important.head()
# Out:
#         date  % Iron Concentrate  % Silica Concentrate  Ore Pulp pH  \
# 0 2017-06-01               64.46                  1.73      9.55029
# 1 2017-06-01               64.46                  1.73      9.55201
# 2 2017-06-01               64.46                  1.73      9.55373
# 3 2017-06-01               64.46                  1.73      9.55544
# 4 2017-06-01               64.46                  1.73      9.55716
#
#    Flotation Column 05 Level
# 0                    522.585
# 1                    497.841
# 2                    473.097
# 3                    455.752
# 4                    475.140

# %%
sns.pairplot(df_june_important)

# %%
# 1. Do the Math (Filter to numeric columns only)
correlation_table = df_june_important.corr(numeric_only=True)

# 2. Draw the Heatmap
sns.heatmap(correlation_table, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
sns.lineplot(x='date', y='% Iron Concentrate', data=df_june)
# Out:
# <Axes: xlabel='date', ylabel='% Iron Concentrate'>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6)) # Increase the chart size (width=12, height=6)

sns.lineplot(x='date', y='% Iron Concentrate', data=df_june)

plt.title('% Iron Concentrate Over Time')
plt.xlabel('Date')
plt.ylabel('% Iron Concentrate')

plt.tight_layout() # Prevent labels from overlapping
plt.show()

# %%
# List of columns we want to plot
columns_to_plot = ['% Iron Concentrate', '% Silica Concentrate', 'Ore Pulp pH', 'Flotation Column 05 Level']

# Loop through the list
for col in columns_to_plot:
    plt.figure(figsize=(12, 6))
    sns.lineplot(x='date', y=col, data=df_june)
    plt.title(col)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7f844409-b9ed-4e88-88c4-8a35c06f3459' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
